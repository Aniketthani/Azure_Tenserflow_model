# %% [markdown]
# # Import packages

# %%
import os
import urllib
import shutil
import azureml

from azureml.core import Experiment
from azureml.core import Workspace, Run
from azureml.core import Environment

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# %% [markdown]
# # Initialize a workspace

# %%
ws = Workspace.from_config()

# %% [markdown]
# # Create a file dataset

# %% [markdown]
# A FileDataset object references one or multiple files in your workspace datastore or public urls. The files can be of any format, and the class provides you with the ability to download or mount the files to your compute. By creating a FileDataset, you create a reference to the data source location. If you applied any transformations to the data set, they will be stored in the data set as well. The data remains in its existing location, so no extra storage cost is incurred.

# %%
from azureml.core.dataset import Dataset

web_paths = [
            'http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz',
            'http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz',
            'http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz',
            'http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz'
            ]
dataset = Dataset.File.from_files(path=web_paths)

# %% [markdown]
# Use the register() method to register the data set to your workspace so they can be shared with others, reused across various experiments, and referred to by name in your training script

# %%
dataset = dataset.register(workspace=ws,
                           name='mnist-dataset',
                           description='training and test dataset',
                           create_new_version=True)

# list the files referenced by dataset
dataset.to_path()
# Out:
# ['/http%3A/%2Fyann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz',
#  '/http%3A/%2Fyann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz',
#  '/http%3A/%2Fyann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz',
#  '/http%3A/%2Fyann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz']

# %% [markdown]
# # Create a compute target

# %% [markdown]
# Create a compute target for your TensorFlow job to run on. In this example, create a GPU-enabled Azure Machine Learning compute cluster.

# %%
cluster_name = "AKTCompute"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_NC6', 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Found existing compute target

# %% [markdown]
# # Create a custom environment
# You can also create your own Azure ML environment that encapsulates your training script's dependencies.
#
# First, define your conda dependencies in a YAML file; in this example the file is named conda_dependencies.yml.

# %% [markdown]
# YAML code
#
# channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-defaults
#   - tensorflow-gpu==2.2.0

# %% [markdown]
# Create an Azure ML environment from this conda environment specification. The environment will be packaged into a Docker container at runtime.

# %% [markdown]
# By default if no base image is specified, Azure ML will use a CPU image azureml.core.environment.DEFAULT_CPU_IMAGE as the base image. Since this example runs training on a GPU cluster, you will need to specify a GPU base image that has the necessary GPU drivers and dependencies. Azure ML maintains a set of base images published on Microsoft Container Registry (MCR) that you can use

# %%
tf_env = Environment.from_conda_specification(name='tensorflow-2.2-gpu', file_path='./conda_dependencies.yml')

# Specify a GPU base image
tf_env.docker.enabled = True
tf_env.docker.base_image = 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04'
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.

# %% [markdown]
# # Configure and submit your training run
# # Create a ScriptRunConfig
# Create a ScriptRunConfig object to specify the configuration details of your training job, including your training script, environment to use, and the compute target to run on. Any arguments to your training script will be passed via command line if specified in the arguments parameter.

# %%
from azureml.core import ScriptRunConfig

args = ['--data-folder', dataset.as_mount(),
        '--batch-size', 64,
        '--first-layer-neurons', 256,
        '--second-layer-neurons', 128,
        '--learning-rate', 0.01]

src = ScriptRunConfig(source_directory="script_folder",
                      script='tf_mnist.py',
                      arguments=args,
                      compute_target=compute_target,
                      environment=tf_env)

# %% [markdown]
# # Submit a run
# The Run object provides the interface to the run history while the job is running and after it has completed.

# %%
run = Experiment(workspace=ws, name='Tutorial-TF-Mnist').submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: Tutorial-TF-Mnist_1631365495_e5327f86
# Web View: https://ml.azure.com/runs/Tutorial-TF-Mnist_1631365495_e5327f86?wsid=/subscriptions/5f142bd4-c7c4-4488-b9b3-3c141b8b11ec/resourcegroups/aktresources/workspaces/aktmlws&tid=0f8a5db0-6b60-4ca8-9fc9-8b2ae1cb809e
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/09/11 13:05:08 Downloading source code...
# 2021/09/11 13:05:10 Finished downloading source code
# 2021/09/11 13:05:10 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/09/11 13:05:11 Successfully set up Docker network: acb_default_network
# 2021/09/11 13:05:11 Setting up Docker configuration...
# 2021/09/11 13:05:11 Successfully set up Docker configuration
# 2021/09/11 13:05:11 Logging in to registry: 836545afbeff4614814992f6794057dc.azurecr.io
# 2021/09/11 13:05:13 Successfully logged into 836545afbeff4614814992f6794057dc.azurecr.io
# 2021/09/11 13:05:13 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/11 13:05:13 Scanning for dependencies...
# 2021/09/11 13:05:13 Successfully scanned dependencies
# 2021/09/11 13:05:13 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04@sha256:4debb59e6da5072bf47cf5763a24495444de520ea5c7b2ce749b38fb7cfd0c34
# mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04@sha256:4debb59e6da5072bf47cf5763a24495444de520ea5c7b2ce749b38fb7cfd0c34: Pulling from azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
# feac53061382: Pulling fs layer
# d28d174ff0e5: Pulling fs layer
# 5c5f4eec362d: Pulling fs layer
# cd3e251986e6: Pulling fs layer
# 31d038adf8de: Pulling fs layer
# 4af0e55fa2ce: Pulling fs layer
# c070774b6baa: Pulling fs layer
# 43161f0cf418: Pulling fs layer
# 373d328f571c: Pulling fs layer
# 3b6ca027437b: Pulling fs layer
# 433cc29572dc: Pulling fs layer
# 9c5161a00f6b: Pulling fs layer
# eec7b6849284: Pulling fs layer
# 2156854b652f: Pulling fs layer
# 2c2b9d595eef: Pulling fs layer
# 7bafb35d24ec: Pulling fs layer
# fd59438c61c9: Pulling fs layer
# d98f79f7fadd: Pulling fs layer
# cd3e251986e6: Waiting
# 31d038adf8de: Waiting
# 4af0e55fa2ce: Waiting
# c070774b6baa: Waiting
# 43161f0cf418: Waiting
# 373d328f571c: Waiting
# 3b6ca027437b: Waiting
# 433cc29572dc: Waiting
# 9c5161a00f6b: Waiting
# eec7b6849284: Waiting
# 2156854b652f: Waiting
# 2c2b9d595eef: Waiting
# 7bafb35d24ec: Waiting
# fd59438c61c9: Waiting
# d98f79f7fadd: Waiting
# d28d174ff0e5: Verifying Checksum
# d28d174ff0e5: Download complete
# 5c5f4eec362d: Verifying Checksum
# 5c5f4eec362d: Download complete
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# cd3e251986e6: Verifying Checksum
# cd3e251986e6: Download complete
# 31d038adf8de: Verifying Checksum
# 31d038adf8de: Download complete
# c070774b6baa: Verifying Checksum
# c070774b6baa: Download complete
# 373d328f571c: Verifying Checksum
# 373d328f571c: Download complete
#
# feac53061382: Pull complete
# 4af0e55fa2ce: Verifying Checksum
# 4af0e55fa2ce: Download complete
# 3b6ca027437b: Verifying Checksum
# 3b6ca027437b: Download complete
# 9c5161a00f6b: Verifying Checksum
# 9c5161a00f6b: Download complete
# eec7b6849284: Verifying Checksum
# eec7b6849284: Download complete
# 433cc29572dc: Verifying Checksum
# 433cc29572dc: Download complete
# 2c2b9d595eef: Verifying Checksum
# 2c2b9d595eef: Download complete
# 7bafb35d24ec: Verifying Checksum
# 7bafb35d24ec: Download complete
# 43161f0cf418: Verifying Checksum
# 43161f0cf418: Download complete
# 2156854b652f: Verifying Checksum
# 2156854b652f: Download complete
# d98f79f7fadd: Verifying Checksum
# d98f79f7fadd: Download complete
# fd59438c61c9: Verifying Checksum
# fd59438c61c9: Download complete
# d28d174ff0e5: Pull complete
# 5c5f4eec362d: Pull complete
# cd3e251986e6: Pull complete
# 31d038adf8de: Pull complete
#
# 4af0e55fa2ce: Pull complete
# c070774b6baa: Pull complete
#
# 43161f0cf418: Pull complete
# 373d328f571c: Pull complete
#
# 3b6ca027437b: Pull complete
# 433cc29572dc: Pull complete
# 9c5161a00f6b: Pull complete
# eec7b6849284: Pull complete
# 2156854b652f: Pull complete
# 2c2b9d595eef: Pull complete
# 7bafb35d24ec: Pull complete
# fd59438c61c9: Pull complete
# d98f79f7fadd: Pull complete
# Digest: sha256:4debb59e6da5072bf47cf5763a24495444de520ea5c7b2ce749b38fb7cfd0c34
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04@sha256:4debb59e6da5072bf47cf5763a24495444de520ea5c7b2ce749b38fb7cfd0c34
#  ---> 278bb6995200
# Step 2/19 : USER root
#  ---> Running in c3dd41d7d6cd
# Removing intermediate container c3dd41d7d6cd
#  ---> 8680aa04b8ad
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in 56bab9d008d3
# Removing intermediate container 56bab9d008d3
#  ---> e4656d84346f
# Step 4/19 : WORKDIR /
#  ---> Running in 40f5eb5ff355
# Removing intermediate container 40f5eb5ff355
#  ---> a739bac4f854
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 081779f9cc3a
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 3f3a154b9331
# Removing intermediate container 3f3a154b9331
#  ---> 40b982515c38
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 1ace33892bf0
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_501e4318608c5015673184f817533f92 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 03612a923b18
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# pip-21.2.4           | 1.1 MB    |            |   0%
# pip-21.2.4           | 1.1 MB    | 1          |   1%
# pip-21.2.4           | 1.1 MB    | ########## | 100%
# pip-21.2.4           | 1.1 MB    | ########## | 100%
#
# libgomp-11.1.0       | 427 KB    |            |   0%
# libgomp-11.1.0       | 427 KB    | ########## | 100%
# libgomp-11.1.0       | 427 KB    | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# readline-6.2         | 713 KB    |            |   0%
# readline-6.2         | 713 KB    | ########## | 100%
# readline-6.2         | 713 KB    | ########## | 100%
#
# python-3.6.2         | 19.0 MB   |            |   0%
# python-3.6.2         | 19.0 MB   | #9         |  19%
# python-3.6.2         | 19.0 MB   | #####8     |  59%
# python-3.6.2         | 19.0 MB   | ########## | 100%
# python-3.6.2         | 19.0 MB   | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
#
# ncurses-5.9          | 1.1 MB    |            |   0%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
#
# zlib-1.2.11          | 106 KB    |            |   0%
# zlib-1.2.11          | 106 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# wheel-0.37.0         | 31 KB     |            |   0%
# wheel-0.37.0         | 31 KB     | ########## | 100%
#
# libgcc-ng-11.1.0     | 908 KB    |            |   0%
# libgcc-ng-11.1.0     | 908 KB    | ########## | 100%
# libgcc-ng-11.1.0     | 908 KB    | ########## | 100%
#
# ca-certificates-2021 | 136 KB    |            |   0%
# ca-certificates-2021 | 136 KB    | ########## | 100%
#
# setuptools-58.0.4    | 940 KB    |            |   0%
# setuptools-58.0.4    | 940 KB    | ########## | 100%
# setuptools-58.0.4    | 940 KB    | ########## | 100%
#
# tk-8.5.19            | 1.9 MB    |            |   0%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# xz-5.2.5             | 343 KB    |            |   0%
# xz-5.2.5             | 343 KB    | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
#
# sqlite-3.13.0        | 4.9 MB    |            |   0%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_501e4318608c5015673184f817533f92/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.w_ruj26y.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.34.0-py3-none-any.whl (3.1 kB)
# Collecting tensorflow-gpu==2.2.0
#   Downloading tensorflow_gpu-2.2.0-cp36-cp36m-manylinux2010_x86_64.whl (516.2 MB)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting google-pasta>=0.1.8
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.40.0-cp36-cp36m-manylinux2014_x86_64.whl (4.3 MB)
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
# Collecting keras-preprocessing>=1.1.0
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting protobuf>=3.8.0
#   Downloading protobuf-3.17.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting absl-py>=0.7.0
#   Downloading absl_py-0.13.0-py3-none-any.whl (132 kB)
# Collecting numpy<2.0,>=1.16.0
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting six>=1.12.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: wheel>=0.26 in /azureml-envs/azureml_501e4318608c5015673184f817533f92/lib/python3.6/site-packages (from tensorflow-gpu==2.2.0->-r /azureml-environment-setup/condaenv.w_ruj26y.requirements.txt (line 2)) (0.37.0)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-inference-server-http~=0.3.1
#   Downloading azureml_inference_server_http-0.3.1-py3-none-any.whl (38 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.34.0
#   Downloading azureml_dataset_runtime-1.34.0-py3-none-any.whl (3.5 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting azureml-core~=1.34.0
#   Downloading azureml_core-1.34.0-py3-none-any.whl (2.2 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_501e4318608c5015673184f817533f92/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.w_ruj26y.requirements.txt (line 1)) (58.0.4)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.7.13-py2.py3-none-any.whl (127 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting docker<6.0.0
#   Downloading docker-5.0.2-py2.py3-none-any.whl (145 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.18.0-py2.py3-none-any.whl (166 kB)
# Collecting azureml-dataprep<2.23.0a,>=2.22.0a
#   Downloading azureml_dataprep-2.22.2-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex~=1.20.0dev0
#   Downloading azureml_dataprep_rslex-1.20.2-cp36-cp36m-manylinux1_x86_64.whl (10.9 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.14.0-py2.py3-none-any.whl (75 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting inference-schema==1.1.0
#   Downloading inference_schema-1.1.0-py3-none-any.whl (19 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting wrapt>=1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<2.0.0,>=1.0.0
#   Downloading google_api_core-1.31.2-py2.py3-none-any.whl (93 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting google-auth<2.0dev,>=1.25.0
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Collecting packaging>=14.3
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Building wheels for collected packages: json-logging-py, wrapt, fusepy, termcolor, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=ec0aff0e62360259e5dd9b15133db3c7448a298af833757b12727d8bd28d290e
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.1-cp36-cp36m-linux_x86_64.whl size=69900 sha256=a9828360823ad7a17eeecbfd681cdcee9af50612d8818121e60fab2504a0e7cb
#   Stored in directory: /root/.cache/pip/wheels/94/0f/ec/66085641573800014bb0c8b657f3366eff641c42df79abbfe9
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=1d810ca1e908fdf8c4207e3ee7b5c580b6c4aec47969251465b1c9f0f46a2a58
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=dd7c978e633658d0a605e5923362212949796b44a043dbffe155521bfe4217fa
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=be1b7b4283222d970b0fea38acde2c84dbacb75d90102e7dc9a2a9f4eb0e614c
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py wrapt fusepy termcolor contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, certifi, requests, typing-extensions, six, pyasn1, portalocker, oauthlib, msal, zipp, rsa, requests-oauthlib, python-dateutil, pyparsing, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, pytz, packaging, numpy, msrest, MarkupSafe, importlib-metadata, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, wrapt, werkzeug, websocket-client, ruamel.yaml.clib, pyopenssl, pyarrow, opencensus-context, msrestazure, Jinja2, jeepney, itsdangerous, google-api-core, click, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, tensorboard-plugin-wit, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, markdown, jsonpickle, jmespath, inference-schema, gunicorn, grpcio, google-auth-oauthlib, fusepy, flask, docker, contextlib2, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, applicationinsights, absl-py, termcolor, tensorflow-estimator, tensorboard, scipy, opt-einsum, opencensus-ext-azure, keras-preprocessing, json-logging-py, h5py, google-pasta, gast, configparser, azureml-inference-server-http, azureml-core, astunparse, tensorflow-gpu, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 absl-py-0.13.0 adal-1.2.7 applicationinsights-0.11.10 astunparse-1.6.3 azure-common-1.1.27 azure-core-1.18.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.34.0 azureml-dataprep-2.22.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.20.2 azureml-dataset-runtime-1.34.0 azureml-defaults-1.34.0 azureml-inference-server-http-0.3.1 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.2 certifi-2021.5.30 cffi-1.14.6 charset-normalizer-2.0.4 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-21.6.0 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-5.0.2 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 gast-0.3.3 google-api-core-1.31.2 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 googleapis-common-protos-1.53.0 grpcio-1.40.0 gunicorn-20.1.0 h5py-2.10.0 idna-3.2 immutables-0.16 importlib-metadata-4.8.1 inference-schema-1.1.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 keras-preprocessing-1.1.2 markdown-3.3.4 msal-1.14.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.1.1 opencensus-0.7.13 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 opt-einsum-3.3.0 packaging-21.0 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.17.3 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-2.4.7 python-dateutil-2.8.2 pytz-2021.1 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 scipy-1.4.1 six-1.16.0 tensorboard-2.2.2 tensorboard-plugin-wit-1.8.0 tensorflow-estimator-2.2.0 tensorflow-gpu-2.2.0 termcolor-1.1.0 typing-extensions-3.10.0.2 urllib3-1.26.6 websocket-client-1.2.1 werkzeug-1.0.1 wrapt-1.11.1 zipp-3.5.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_501e4318608c5015673184f817533f92
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 03612a923b18
#  ---> c0c3a3c89018
# Step 9/19 : ENV PATH /azureml-envs/azureml_501e4318608c5015673184f817533f92/bin:$PATH
#  ---> Running in 6526327911d2
# Removing intermediate container 6526327911d2
#  ---> b74f2a159f9d
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 30ca48a8204a
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in 09eea6445502
# Copying environment context
# Removing intermediate container 09eea6445502
#  ---> a313eeaf5d38
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> b0c9db3ba47d
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_501e4318608c5015673184f817533f92
#  ---> Running in 5bfa15fb6c37
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 5bfa15fb6c37
#  ---> c02a59674c14
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_501e4318608c5015673184f817533f92
#  ---> Running in 5dfac0bb14c4
# Removing intermediate container 5dfac0bb14c4
#  ---> 6efc798a4fcb
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_501e4318608c5015673184f817533f92/lib:$LD_LIBRARY_PATH
#  ---> Running in a2a82c936a81
# Removing intermediate container a2a82c936a81
#  ---> 28631d3674be
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 77b6aff5318e
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 0afd8f955b00
# Removing intermediate container 0afd8f955b00
#  ---> 7f0c335076c3
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 73dfe9ca77d6
# Removing intermediate container 73dfe9ca77d6
#  ---> c3eb09bd12fb
# Step 19/19 : CMD ["bash"]
#  ---> Running in 788eccf8aa43
# Removing intermediate container 788eccf8aa43
#  ---> a8d4acd4c18f
# Successfully built a8d4acd4c18f
# Successfully tagged 836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1:latest
# Successfully tagged 836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1:1
# 2021/09/11 13:11:23 Successfully executed container: acb_step_0
# 2021/09/11 13:11:23 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/11 13:11:23 Pushing image: 836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1:1, attempt 1
# The push refers to repository [836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1]
# 041f64f266f1: Preparing
# fa8d27036bea: Preparing
# 39b3987dec58: Preparing
# f0636d40cc69: Preparing
# ff854ae4db10: Preparing
# 07cd029d6991: Preparing
# 14e29eb2c386: Preparing
# 54422ee3040e: Preparing
# dc520203ed76: Preparing
# 476e5024ed0a: Preparing
# 5061a51c5398: Preparing
# e684c0c47e65: Preparing
# bdc9f09285f9: Preparing
# ecb8ecfab974: Preparing
# 47ef9e4e719b: Preparing
# b41c778ec735: Preparing
# 4fe14301f0c9: Preparing
# 3152e41e5034: Preparing
# 6348f543dd09: Preparing
# 337ab38b7a53: Preparing
# be343531f050: Preparing
# a9907549bd25: Preparing
# 4cb0116970cc: Preparing
# bc846871b979: Preparing
# e1aa27fd16c4: Preparing
# 66ee74417c3b: Preparing
# 21639b09744f: Preparing
# 07cd029d6991: Waiting
# 14e29eb2c386: Waiting
# 54422ee3040e: Waiting
# dc520203ed76: Waiting
# 476e5024ed0a: Waiting
# 5061a51c5398: Waiting
# e684c0c47e65: Waiting
# bdc9f09285f9: Waiting
# ecb8ecfab974: Waiting
# 47ef9e4e719b: Waiting
# b41c778ec735: Waiting
# 4fe14301f0c9: Waiting
# 3152e41e5034: Waiting
# 6348f543dd09: Waiting
# 337ab38b7a53: Waiting
# be343531f050: Waiting
# a9907549bd25: Waiting
# 4cb0116970cc: Waiting
# bc846871b979: Waiting
# e1aa27fd16c4: Waiting
# 66ee74417c3b: Waiting
# 21639b09744f: Waiting
# f0636d40cc69: Pushed
# 39b3987dec58: Pushed
# 041f64f266f1: Pushed
# fa8d27036bea: Pushed
# 07cd029d6991: Pushed
# 14e29eb2c386: Pushed
# 54422ee3040e: Pushed
# dc520203ed76: Pushed
# 476e5024ed0a: Pushed
# 5061a51c5398: Pushed
# e684c0c47e65: Pushed
# bdc9f09285f9: Pushed
# 47ef9e4e719b: Pushed
# b41c778ec735: Pushed
# ecb8ecfab974: Pushed
# 6348f543dd09: Pushed
# be343531f050: Pushed
# 4fe14301f0c9: Pushed
# 4cb0116970cc: Pushed
# bc846871b979: Pushed
# e1aa27fd16c4: Pushed
# 66ee74417c3b: Pushed
# 3152e41e5034: Pushed
# 21639b09744f: Pushed
# a9907549bd25: Pushed
# 337ab38b7a53: Pushed
# ff854ae4db10: Pushed
# 1: digest: sha256:f3a7b5e694a1515e1011b85ea8e3eace1585c0aa3bf337f8155967a04ed2970e size: 5992
# 2021/09/11 13:16:36 Successfully pushed image: 836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1:1
# 2021/09/11 13:16:36 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/11 13:16:36 Pushing image: 836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1:latest, attempt 1
# The push refers to repository [836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1]
# 041f64f266f1: Preparing
# fa8d27036bea: Preparing
# 39b3987dec58: Preparing
# f0636d40cc69: Preparing
# ff854ae4db10: Preparing
# 07cd029d6991: Preparing
# 14e29eb2c386: Preparing
# 54422ee3040e: Preparing
# dc520203ed76: Preparing
# 476e5024ed0a: Preparing
# 5061a51c5398: Preparing
# e684c0c47e65: Preparing
# bdc9f09285f9: Preparing
# ecb8ecfab974: Preparing
# 47ef9e4e719b: Preparing
# b41c778ec735: Preparing
# 4fe14301f0c9: Preparing
# 3152e41e5034: Preparing
# 6348f543dd09: Preparing
# 337ab38b7a53: Preparing
# be343531f050: Preparing
# a9907549bd25: Preparing
# 4cb0116970cc: Preparing
# bc846871b979: Preparing
# e1aa27fd16c4: Preparing
# 66ee74417c3b: Preparing
# 21639b09744f: Preparing
# 07cd029d6991: Waiting
# 4fe14301f0c9: Waiting
# 3152e41e5034: Waiting
# 6348f543dd09: Waiting
# 14e29eb2c386: Waiting
# 337ab38b7a53: Waiting
# be343531f050: Waiting
# 54422ee3040e: Waiting
# dc520203ed76: Waiting
# 476e5024ed0a: Waiting
# 5061a51c5398: Waiting
# a9907549bd25: Waiting
# e684c0c47e65: Waiting
# bdc9f09285f9: Waiting
# 4cb0116970cc: Waiting
# ecb8ecfab974: Waiting
# 47ef9e4e719b: Waiting
# b41c778ec735: Waiting
# bc846871b979: Waiting
# 21639b09744f: Waiting
# e1aa27fd16c4: Waiting
# 66ee74417c3b: Waiting
# ff854ae4db10: Layer already exists
# f0636d40cc69: Layer already exists
# 39b3987dec58: Layer already exists
# 07cd029d6991: Layer already exists
# 14e29eb2c386: Layer already exists
# 041f64f266f1: Layer already exists
# 54422ee3040e: Layer already exists
# dc520203ed76: Layer already exists
# fa8d27036bea: Layer already exists
# 5061a51c5398: Layer already exists
# 476e5024ed0a: Layer already exists
# ecb8ecfab974: Layer already exists
# 47ef9e4e719b: Layer already exists
# e684c0c47e65: Layer already exists
# bdc9f09285f9: Layer already exists
# b41c778ec735: Layer already exists
# 4fe14301f0c9: Layer already exists
# 3152e41e5034: Layer already exists
# 337ab38b7a53: Layer already exists
# be343531f050: Layer already exists
# a9907549bd25: Layer already exists
# 66ee74417c3b: Layer already exists
# e1aa27fd16c4: Layer already exists
# 4cb0116970cc: Layer already exists
# bc846871b979: Layer already exists
# 21639b09744f: Layer already exists
# 6348f543dd09: Layer already exists
# latest: digest: sha256:f3a7b5e694a1515e1011b85ea8e3eace1585c0aa3bf337f8155967a04ed2970e size: 5992
# 2021/09/11 13:16:38 Successfully pushed image: 836545afbeff4614814992f6794057dc.azurecr.io/azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1:latest
# 2021/09/11 13:16:38 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 370.618460)
# 2021/09/11 13:16:38 Populating digests for step ID: acb_step_0...
# 2021/09/11 13:16:40 Successfully populated digests for step ID: acb_step_0
# 2021/09/11 13:16:40 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 313.064356)
# 2021/09/11 13:16:40 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.988546)
# 2021/09/11 13:16:40 The following dependencies were found:
# 2021/09/11 13:16:40
# - image:
#     registry: 836545afbeff4614814992f6794057dc.azurecr.io
#     repository: azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1
#     tag: latest
#     digest: sha256:f3a7b5e694a1515e1011b85ea8e3eace1585c0aa3bf337f8155967a04ed2970e
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
#     digest: sha256:4debb59e6da5072bf47cf5763a24495444de520ea5c7b2ce749b38fb7cfd0c34
#   git: {}
# - image:
#     registry: 836545afbeff4614814992f6794057dc.azurecr.io
#     repository: azureml/azureml_51d4574c37c51c55fdd4cc9d2cedbbb1
#     tag: "1"
#     digest: sha256:f3a7b5e694a1515e1011b85ea8e3eace1585c0aa3bf337f8155967a04ed2970e
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
#     digest: sha256:4debb59e6da5072bf47cf5763a24495444de520ea5c7b2ce749b38fb7cfd0c34
#   git: {}
#
#
# Run ID: cj1 was successful after 11m33s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt
# ========================================================================================================================
#
# 2021-09-11T13:20:35Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=78217 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-09-11T13:20:35Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/mounts/workspaceblobstore
# 2021-09-11T13:20:35Z The vmsize standard_d11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-11T13:20:35Z Starting output-watcher...
# 2021-09-11T13:20:35Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-09-11T13:20:36Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-09-11T13:20:36Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1e5b59c0734bdc528077f509e1d397fe
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 886c27cf0865: Pulling fs layer
# 7c9062f12448: Pulling fs layer
# 7268e886f68a: Pulling fs layer
# e1fdaab561c7: Pulling fs layer
# ccb2816215bd: Pulling fs layer
# 55d70b17f345: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 886c27cf0865: Waiting
# 7c9062f12448: Waiting
# 7268e886f68a: Waiting
# e1fdaab561c7: Waiting
# ccb2816215bd: Waiting
# 55d70b17f345: Waiting
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 886c27cf0865: Verifying Checksum
# 886c27cf0865: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 7268e886f68a: Verifying Checksum
# 7268e886f68a: Download complete
# e1fdaab561c7: Verifying Checksum
# e1fdaab561c7: Download complete
# ccb2816215bd: Verifying Checksum
# ccb2816215bd: Download complete
# 55d70b17f345: Verifying Checksum
# 55d70b17f345: Download complete
# 7c9062f12448: Verifying Checksum
# 7c9062f12448: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 886c27cf0865: Pull complete
# 7c9062f12448: Pull complete
# 7268e886f68a: Pull complete
# e1fdaab561c7: Pull complete
# ccb2816215bd: Pull complete
# 55d70b17f345: Pull complete
# Digest: sha256:d0c5e40cf440c619e721faa614dc94fe56cb6c41768532d169421cbe2288edc7
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_1e5b59c0734bdc528077f509e1d397fe:latest
# viennaglobal.azurecr.io/azureml/azureml_1e5b59c0734bdc528077f509e1d397fe:latest
# 2021-09-11T13:22:14Z The vmsize standard_d11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-11T13:22:14Z Check if container tutorial-tf-mnist_1631365495_e5327f86_DataSidecar already exist exited with 0,
#
# 187bd83f7f5982e5634d1c181720d9ed590d3b3389abf6ca9e412595a585987e
# 2021-09-11T13:22:16Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-09-11T13:22:16Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-8cda38a3e97ee86a44935d1eb663df91-3eb3431fef0c3318-01 -sshRequired=false]
# 2021/09/11 13:22:16 Starting App Insight Logger for task:  containerSetup
# 2021/09/11 13:22:16 Version: 3.0.01706.0003 Branch: 2021-09-03 Commit: cd0f702
# 2021/09/11 13:22:16 Entered ContainerSetupTask - Preparing infiniband
# 2021/09/11 13:22:16 Starting infiniband setup
# 2021/09/11 13:22:16 Python Version found is Python 3.7.9
#
# 2021/09/11 13:22:16 Returning Python Version as 3.7
# 2021-09-11T13:22:16Z VMSize: standard_d11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021-09-11T13:22:16Z Not setting up Infiniband in Container
# 2021/09/11 13:22:16 VMSize: standard_d11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/09/11 13:22:16 VMSize: standard_d11_v2, Host: ubuntu-18, Container: ubuntu-16.04
# 2021/09/11 13:22:16 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/09/11 13:22:16 Not setting up Infiniband in Container
# 2021/09/11 13:22:16 Not setting up Infiniband in Container
# 2021/09/11 13:22:16 Python Version found is Python 3.7.9
#
# 2021/09/11 13:22:16 Returning Python Version as 3.7
# 2021/09/11 13:22:16 sshd inside container not required for job, skipping setup.
# 2021/09/11 13:22:17 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/09/11 13:22:17 App Insight Client has already been closed
# 2021/09/11 13:22:17 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-09-11T13:22:17Z Starting docker container succeeded.
# 2021-09-11T13:22:17Z The vmsize standard_d11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
#
# Streaming azureml-logs/65_job_prep-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt
# ===============================================================================================================
#
# [2021-09-11T13:22:19.632072] Entering job preparation.
# [2021-09-11T13:22:20.299361] Starting job preparation.
# [2021-09-11T13:22:20.299395] Extracting the control code.
# [2021-09-11T13:22:20.299734] Starting extract_project.
# [2021-09-11T13:22:20.299772] Starting to extract zip file.
# [2021-09-11T13:22:20.317530] Finished extracting zip file.
# [2021-09-11T13:22:20.321778] Using urllib.request Python 3.0 or later
# [2021-09-11T13:22:20.322043] Start fetching snapshots.
# [2021-09-11T13:22:20.322377] Start fetching snapshot.
# [2021-09-11T13:22:20.322546] Retrieving project from snapshot: 7fb9d847-52e3-48a5-97c0-b82b3f3c4dda
# Starting the daemon thread to refresh tokens in background for process with pid = 43
# [2021-09-11T13:22:20.641991] Finished fetching snapshot.
# [2021-09-11T13:22:20.642027] Finished fetching snapshots.
# [2021-09-11T13:22:20.642038] Finished extract_project.
# [2021-09-11T13:22:20.642307] Finished fetching and extracting the control code.
# [2021-09-11T13:22:20.650086] Start run_history_prep.
# [2021-09-11T13:22:20.659119] Job preparation is complete.
# [2021-09-11T13:22:20.659289] Entering Data Context Managers in Sidecar
# [2021-09-11T13:22:20.660269] Running Sidecar prep cmd...
# [2021-09-11T13:22:21.143227] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/azureml/Tutorial-TF-Mnist_1631365495_e5327f86
# [2021-09-11T13:22:21.144237] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.32.0 azureml-dataprep==2.20.1. Session id: 12d5be19-4ae5-40ab-970e-d4420ef2d8cc. Run id: Tutorial-TF-Mnist_1631365495_e5327f86.
# Processing 'input__8be8af44'.
# Mode: 'mount'.
# Path on compute is specified: 'False'.
# Processing dataset FileDataset
# {
#   "source": [
#     "http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz",
#     "http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "8be8af44-176d-4a38-a714-31d0e23975ac",
#     "name": "mnist-dataset",
#     "version": 1,
#     "description": "training and test dataset",
#     "workspace": "Workspace.create(name='aktmlws', subscription_id='5f142bd4-c7c4-4488-b9b3-3c141b8b11ec', resource_group='aktresources')"
#   }
# }
# Mounting input__8be8af44 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac.
# Mounted input__8be8af44 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__8be8af44's target path to /mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac
# [2021-09-11T13:22:33.338058] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-09-11T13:22:33.810817] Ran Sidecar prep cmd.
# [2021-09-11T13:22:33.810917] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_501e4318608c5015673184f817533f92/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/09/11 13:27:21 Starting App Insight Logger for task:  runTaskLet
# 2021/09/11 13:27:21 Version: 3.0.01706.0003 Branch: 2021-09-03 Commit: cd0f702
# 2021/09/11 13:27:21 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# bash: /azureml-envs/azureml_501e4318608c5015673184f817533f92/lib/libtinfo.so.5: no version information available (required by bash)
# 2021/09/11 13:27:21 Send process info logs to master server succeeded
# 2021/09/11 13:27:21 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/09/11 13:27:21 Send process info logs to master server succeeded
# [2021-09-11T13:27:21.494883] Entering context manager injector.
# [2021-09-11T13:27:22.144899] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['tf_mnist.py', '--data-folder', 'DatasetConsumptionConfig:input__8be8af44', '--batch-size', '64', '--first-layer-neurons', '256', '--second-layer-neurons', '128', '--learning-rate', '0.01'])
# Script type = None
# [2021-09-11T13:27:22.149788] Entering Run History Context Manager.
# [2021-09-11T13:27:22.996660] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/azureml/Tutorial-TF-Mnist_1631365495_e5327f86
# [2021-09-11T13:27:22.996715] Preparing to call script [tf_mnist.py] with arguments:['--data-folder', '$input__8be8af44', '--batch-size', '64', '--first-layer-neurons', '256', '--second-layer-neurons', '128', '--learning-rate', '0.01']
# [2021-09-11T13:27:22.996744] After variable expansion, calling script [tf_mnist.py] with arguments:['--data-folder', '/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac', '--batch-size', '64', '--first-layer-neurons', '256', '--second-layer-neurons', '128', '--learning-rate', '0.01']
#
# TensorFlow version: 2.2.0
# Data folder: /mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac
# 2021/09/11 13:27:26 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
# ...
# 2021-09-11 13:27:27.799898: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2397220000 Hz
# 2021-09-11 13:27:27.800098: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f1d34000b20 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-09-11 13:27:27.800122: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 0 -- Training accuracy: tf.Tensor(0.921875, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.8939, shape=(), dtype=float32)
# 1 -- Training accuracy: tf.Tensor(0.921875, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9151, shape=(), dtype=float32)
# 2 -- Training accuracy: tf.Tensor(0.9375, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9212, shape=(), dtype=float32)
# 3 -- Training accuracy: tf.Tensor(0.921875, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9321, shape=(), dtype=float32)
# 4 -- Training accuracy: tf.Tensor(0.953125, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9345, shape=(), dtype=float32)
# 5 -- Training accuracy: tf.Tensor(0.953125, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9407, shape=(), dtype=float32)
# 6 -- Training accuracy: tf.Tensor(0.9375, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9439, shape=(), dtype=float32)
# 7 -- Training accuracy: tf.Tensor(0.953125, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9473, shape=(), dtype=float32)
# 8 -- Training accuracy: tf.Tensor(0.96875, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9494, shape=(), dtype=float32)
# 9 -- Training accuracy: tf.Tensor(0.984375, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9526, shape=(), dtype=float32)
# 10 -- Training accuracy: tf.Tensor(0.984375, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.955, shape=(), dtype=float32)
# 11 -- Training accuracy: tf.Tensor(0.953125, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9563, shape=(), dtype=float32)
# 12 -- Training accuracy: tf.Tensor(0.953125, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9582, shape=(), dtype=float32)
# 13 -- Training accuracy: tf.Tensor(0.96875, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9604, shape=(), dtype=float32)
# 14 -- Training accuracy: tf.Tensor(0.984375, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9612, shape=(), dtype=float32)
# 15 -- Training accuracy: tf.Tensor(0.984375, shape=(), dtype=float32) Validation accuracy: tf.Tensor(0.9634, shape=(), dtype=float32)
#
# Streaming azureml-logs/75_job_post-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt
# ===============================================================================================================
#
# [2021-09-11T13:29:49.899888] Entering job release
# [2021-09-11T13:29:50.853902] Starting job release
# [2021-09-11T13:29:50.854583] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 587
# [2021-09-11T13:29:50.855047] job release stage : upload_datastore starting...
# [2021-09-11T13:29:50.867957] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-09-11T13:29:50.868622] job release stage : execute_job_release starting...
# [2021-09-11T13:29:50.870425] Entering context manager injector.
# [2021-09-11T13:29:50.871028] job release stage : copy_batchai_cached_logs starting...
# [2021-09-11T13:29:50.871525] job release stage : copy_batchai_cached_logs completed...
# [2021-09-11T13:29:50.874087] job release stage : upload_datastore completed...
# [2021-09-11T13:29:50.938227] job release stage : send_run_telemetry starting...
# [2021-09-11T13:29:50.956931] get vm size and vm region successfully.
# [2021-09-11T13:29:50.970575] get compute meta data successfully.
# [2021-09-11T13:29:51.076596] job release stage : execute_job_release completed...
# [2021-09-11T13:29:51.152323] post artifact meta request successfully.
# [2021-09-11T13:29:51.239249] upload compute record artifact successfully.
# [2021-09-11T13:29:51.239334] job release stage : send_run_telemetry completed...
# [2021-09-11T13:29:51.239644] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-09-11T13:29:51.239731] Running Sidecar release cmd...
# [2021-09-11T13:29:51.251327] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/azureml/Tutorial-TF-Mnist_1631365495_e5327f86
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aktmlws/azureml/tutorial-tf-mnist_1631365495_e5327f86/wd/input__8be8af44_8be8af44-176d-4a38-a714-31d0e23975ac.
# Exit __exit__ of DatasetContextManager
# [2021-09-11T13:29:51.294703] Removing absolute paths from host...
# [2021-09-11T13:29:51.294939] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-09-11T13:29:52.245954] Ran Sidecar release cmd.
# [2021-09-11T13:29:52.246049] Job release is complete
#
# Execution Summary
# =================
# RunId: Tutorial-TF-Mnist_1631365495_e5327f86
# Web View: https://ml.azure.com/runs/Tutorial-TF-Mnist_1631365495_e5327f86?wsid=/subscriptions/5f142bd4-c7c4-4488-b9b3-3c141b8b11ec/resourcegroups/aktresources/workspaces/aktmlws&tid=0f8a5db0-6b60-4ca8-9fc9-8b2ae1cb809e
# {'runId': 'Tutorial-TF-Mnist_1631365495_e5327f86',
#  'target': 'AKTCompute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-09-11T13:20:33.945698Z',
#  'endTimeUtc': '2021-09-11T13:30:30.684209Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '7fb9d847-52e3-48a5-97c0-b82b3f3c4dda',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': '8be8af44-176d-4a38-a714-31d0e23975ac'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input__8be8af44', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'tf_mnist.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-folder',
#    'DatasetConsumptionConfig:input__8be8af44',
#    '--batch-size',
#    '64',
#    '--first-layer-neurons',
#    '256',
#    '--second-layer-neurons',
#    '128',
#    '--learning-rate',
#    '0.01'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'AKTCompute',
#   'dataReferences': {},
#   'data': {'input__8be8af44': {'dataLocation': {'dataset': {'id': '8be8af44-176d-4a38-a714-31d0e23975ac',
#       'name': 'mnist-dataset',
#       'version': '1'},
#      'dataPath': None,
#      'uri': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input__8be8af44',
#     'pathOnCompute': None,
#     'overwrite': False,
#     'options': None}},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'tensorflow-2.2-gpu',
#    'version': 'Autosave_2021-09-11T13:04:58Z_546695e6',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults', 'tensorflow-gpu==2.2.0']}],
#      'name': 'azureml_501e4318608c5015673184f817533f92'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': [],
#   'dataBricks': {'workers': 0,
#    'minimumWorkerCount': 0,
#    'maxMumWorkerCount': 0,
#    'sparkVersion': '4.0.x-scala2.11',
#    'nodeTypeId': 'Standard_D3_v2',
#    'sparkConf': {},
#    'sparkEnvVars': {},
#    'instancePoolId': None,
#    'timeoutSeconds': 0,
#    'jarLibraries': [],
#    'eggLibraries': [],
#    'whlLibraries': [],
#    'pypiLibraries': [],
#    'rCranLibraries': [],
#    'mavenLibraries': []}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=1BCH5oDo%2B8bdXbSE6OWDO4ap587KmBFhXsZ%2BfHd0wUs%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/55_azureml-execution-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt?sv=2019-07-07&sr=b&sig=s8Q6jBl6%2FsbvmHNMFyr3kZ%2FDUzgGo2ly8J2jx%2Bug8Sw%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/65_job_prep-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt?sv=2019-07-07&sr=b&sig=xRpkVGOwzweektxq%2BygtYgD61q6olny%2BeUbV8dTBAvI%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/70_driver_log.txt?sv=2019-07-07&sr=b&sig=OJ6VCoX0PgYzG3ifZdit6tFZeHnHnz06QDBlBzUHr%2Bk%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/75_job_post-tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d.txt?sv=2019-07-07&sr=b&sig=eaCsmziiitMkzEr2KgvNdvftrJzfMr%2FYR270WZXcZIM%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'azureml-logs/process_info.json': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/process_info.json?sv=2019-07-07&sr=b&sig=Kt6Fpimt%2FONLVIgc0CeZG8WV6YwJdAKvyy2Jbgfiz4c%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'azureml-logs/process_status.json': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/azureml-logs/process_status.json?sv=2019-07-07&sr=b&sig=53POZ5vzyj46T6OiFmcFdKbvBBLTIHlsa8o8bYH9Vqk%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/74_azureml.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/74_azureml.log?sv=2019-07-07&sr=b&sig=uUZ7llFmHXp6WO%2FAHCeoKFIfr7KWY9oLvmhBQgDSulI%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/dataprep/backgroundProcess.log?sv=2019-07-07&sr=b&sig=%2Fr0eg%2FAs%2BlfTGsd%2BXRbOBvLlRKV4tfZiB8Erqn8ODCw%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-07-07&sr=b&sig=siSSW2OrHEOovn1BYdk6akkk84jRVnBlfIoxeIGkXj8%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/job_prep_azureml.log?sv=2019-07-07&sr=b&sig=huhmVSTqIhGnW4o9bTKPLRDVZEhNLi%2B%2FfBqBpARkuU0%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/job_release_azureml.log?sv=2019-07-07&sr=b&sig=QCbRR2C%2BMYJCR8Ay%2FpX66%2F%2FxYUeMzYnQU75G6np8TNY%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/sidecar/tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d/all.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/sidecar/tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d/all.log?sv=2019-07-07&sr=b&sig=tz6V3x1P8gx%2FNGfuikaqTax986HQ%2FywRlrqAOVClBEg%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/sidecar/tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d/task.enter_contexts.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/sidecar/tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d/task.enter_contexts.log?sv=2019-07-07&sr=b&sig=nHe5k3OW5u8mxUjSGH71YZHgAOHYzStgN2hITHSidOI%3D&st=2021-09-11T13%3A20%3A34Z&se=2021-09-11T21%3A30%3A34Z&sp=r',
#   'logs/azureml/sidecar/tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d/task.exit_contexts.log': 'https://aktmlws8178488858.blob.core.windows.net/azureml/ExperimentRun/dcid.Tutorial-TF-Mnist_1631365495_e5327f86/logs/azureml/sidecar/tvmps_fc2bd83794f79db486d20695c9da21f26597c47ef85df20616e7718968b6b2a5_d/task.exit_contexts.log?sv=2019-07-07&sr=b&sig=AGQ%2BewaXEtV6wkQ10u8ifhzBHlsXSWhPZ2fpIGprM6I%3D&st=2021-09-11T13%3A20%3A35Z&se=2021-09-11T21%3A30%3A35Z&sp=r'},
#  'submittedBy': 'Ravi Changle'}

# %% [markdown]
# # Register a model
# Once you've trained the model, you can register it to your workspace.

# %%
from azureml.core import Model
from azureml.core.resource_configuration import ResourceConfiguration

model = run.register_model(model_name='tf-mnist', 
                           model_path='outputs/model',
                           model_framework=Model.Framework.TENSORFLOW,
                           model_framework_version='2.0',
                           resource_configuration=ResourceConfiguration(cpu=1, memory_in_gb=0.5))
